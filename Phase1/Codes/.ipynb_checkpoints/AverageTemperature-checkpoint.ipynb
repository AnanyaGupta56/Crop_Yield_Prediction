# %%
#Importing Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import mean_squared_error,r2_score

# %%
#Importing the dataset
avgtemp = pd.read_csv(
    r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\AverageTemperature\avgtemp.csv"
)

# %%
avgtemp
# Out:
#      avgtemp_past  avgtemp_pasttopast  avgtemp
# 0           16.85               18.46    17.89
# 1           20.22               17.85    16.60
# 2           18.30               19.64    18.02
# 3           14.86               17.75    16.72
# 4           15.28               13.03    14.20
# ..            ...                 ...      ...
# 211          8.12                8.78     8.78
# 212         10.91                8.60     8.60
# 213         13.51               10.03    10.03
# 214         14.70               14.19    14.19
# 215         16.18               14.96    14.96
#
# [216 rows x 3 columns]

# %%
avgtemp.shape
# Out:
# (216, 3)

# %%
avgtemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   avgtemp_past        216 non-null    float64
#  1   avgtemp_pasttopast  216 non-null    float64
#  2   avgtemp             216 non-null    float64
# dtypes: float64(3)
# memory usage: 5.2 KB

# %%
#Creating correlation matrix for precipitation
corr_matrix=avgtemp.corr()
corr_matrix
# Out:
#                     avgtemp_past  avgtemp_pasttopast   avgtemp
# avgtemp_past            1.000000            0.921491  0.920216
# avgtemp_pasttopast      0.921491            1.000000  0.933440
# avgtemp                 0.920216            0.933440  1.000000

# %%
mask = np.zeros_like(corr_matrix, dtype=bool)
mask[np.triu_indices_from(mask)]= True

# %%
# f, ax = plt.subplots(figsize=(5, 4)) 
# heatmap = sns.heatmap(corr_matrix, mask = mask,square = True,linewidths = .5, cmap = 'coolwarm', cbar_kws = {'shrink': .4, 'ticks' : [-1, -.5, 0, 0.5, 1]},vmin = -1, vmax = 1,annot = True,annot_kws = {'size': 12})
# #add the column names as labels
# ax.set_yticklabels(corr_matrix.columns, rotation = 0)
# ax.set_xticklabels(corr_matrix.columns)
# sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

plt.figure(figsize=(5, 4))

sns.heatmap(
    corr_matrix,
    mask=mask,
    square=True,
    linewidths=0.5,
    cmap='coolwarm',
    cbar_kws={'shrink': 0.4, 'ticks': [-1, -0.5, 0, 0.5, 1]},
    vmin=-1,
    vmax=1,
    annot=True,
    annot_kws={'size': 10}
)

plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
avgtemp=avgtemp.drop(['Year','Month'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 avgtemp=avgtemp.drop(['Year','Month'],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Year', 'Month'] not found in axis"

# %%
avgtemp.shape
# Out:
# (216, 3)

# %%
X=avgtemp.drop('avgtemp',axis=1)
y=avgtemp.avgtemp

# %%
X
# Out:
#      avgtemp_past  avgtemp_pasttopast
# 0           16.85               18.46
# 1           20.22               17.85
# 2           18.30               19.64
# 3           14.86               17.75
# 4           15.28               13.03
# ..            ...                 ...
# 211          8.12                8.78
# 212         10.91                8.60
# 213         13.51               10.03
# 214         14.70               14.19
# 215         16.18               14.96
#
# [216 rows x 2 columns]

# %%
y
# Out:
# 0      17.89
# 1      16.60
# 2      18.02
# 3      16.72
# 4      14.20
#        ...
# 211     8.78
# 212     8.60
# 213    10.03
# 214    14.19
# 215    14.96
# Name: avgtemp, Length: 216, dtype: float64

# %%
X.shape
# Out:
# (216, 2)

# %%
y.shape
# Out:
# (216,)

# %%
#Creating Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=101)

# %%
X_train,y_train=np.array(X_train),np.array(y_train)

# %% [markdown]
# ### Linear Regressor

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
li=LinearRegression()

# %%
li.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction of values
Lir_ypred= li.predict(X_test)
Lir_ypred
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([16.47398943,  6.79206524, 10.50365241, 17.78873834, 17.81822148,
#        12.37611495, 16.93412529,  7.81480162,  8.83353309,  9.65082215,
#        11.00822127,  8.44399542, 11.83382044, 17.07348237,  9.72716317,
#        17.59538832, 16.35221708, 16.11384847,  7.68847644, 15.57420765,
#        14.53091374,  9.37479548])

# %%
#print('Mean Absolute Error:',mean_absolute_error(y_test,Lir_ypred))
print('Mean squared Error:',mean_squared_error(y_test,Lir_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lir_ypred)))
#print('R2_Score:',r2_score(y_test,Lir_ypred))
# Out:
# Mean squared Error: 1.7419698849604552
# Root Mean Squared Error: 1.3198370675808644

# %%
linear_r2_score=r2_score(y_test,Lir_ypred)
linear_r2_score
# Out:
# 0.8807783388535538

# %% [markdown]
# ### Lasso Regressor

# %%
#Lasso Regressor
lass=Lasso(alpha=0.0001)
lass.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
Lass_ypred= lass.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but Lasso was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,Lass_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lass_ypred)))
#print('R2_Score:',r2_score(y_test,Lass_ypred))
# Out:
# Mean squared Error: 1.7418991349531223
# Root Mean Squared Error: 1.319810264755174

# %%
lasso_r2_score=r2_score(y_test,Lass_ypred)
lasso_r2_score
# Out:
# 0.8807831810345084

# %% [markdown]
# ### Ridge Regressor

# %%
#RIdge
rid=Ridge(alpha=0.0001)
rid.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
rid_ypred= rid.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but Ridge was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,rid_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rid_ypred)))
#print('R2_Score:',r2_score(y_test,rid_ypred))
# Out:
# Mean squared Error: 1.7419698362920177
# Root Mean Squared Error: 1.3198370491435742

# %%
ridge_r2_score=r2_score(y_test,rid_ypred)
ridge_r2_score
# Out:
# 0.8807783421844564

# %% [markdown]
# ### Decision Tree Regressor

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_ypred= dt.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,dt_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dt_ypred)))
#print('R2_Score:',r2_score(y_test,dt_ypred))
# Out:
# Mean squared Error: 3.698495454545454
# Root Mean Squared Error: 1.9231472784333117

# %%
decisiontree_r2_score=r2_score(y_test,dt_ypred)
decisiontree_r2_score
# Out:
# 0.7468723336491552

# %% [markdown]
# ### KNeighbour Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn=KNeighborsRegressor(n_neighbors=14)
kn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=14)

# %%
kn1_pred=kn.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,kn1_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,kn1_pred)))
#print('R2_Score:',r2_score(y_test,kn1_pred))
# Out:
# Mean squared Error: 1.6402280148423019
# Root Mean Squared Error: 1.280713869231649

# %%
kneighbour_r2_score=r2_score(y_test,kn1_pred)
kneighbour_r2_score
# Out:
# 0.887741624997796

# %% [markdown]
# ### SVR Regressor

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf')
svr.fit(X_train,y_train)
svr_pred=svr.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,svr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,svr_pred)))
#print('R2_Score:',r2_score(y_test,svr_pred))
# Out:
# Mean squared Error: 1.646794809512616
# Root Mean Squared Error: 1.283275032684972

# %%
svr_r2_score=r2_score(y_test,svr_pred)
svr_r2_score
# Out:
# 0.8872921888876991

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train);

# %%
rf_pred=rf.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,rf_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rf_pred)))
#print('R2_Score:',r2_score(y_test,rf_pred))
# Out:
# Mean squared Error: 1.9720438881454563
# Root Mean Squared Error: 1.4042948010106198

# %%
randomforest_r2_score=r2_score(y_test,rf_pred)
randomforest_r2_score
# Out:
# 0.8650319100070234

# %% [markdown]
# ### Bayes Regressor

# %%
from sklearn.linear_model import BayesianRidge
br=BayesianRidge()
br.fit(X_train,y_train)
# Out:
# BayesianRidge()

# %%
br_pred=br.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but BayesianRidge was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,br_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,br_pred)))
print('R2_Score:',r2_score(y_test,br_pred))
# Out:
# Mean squared Error: 1.7388230254956292
# Root Mean Squared Error: 1.3186443893239865
# R2_Score: 0.8809937121593899

# %%
bayes_r2_score=r2_score(y_test,br_pred)
bayes_r2_score
# Out:
# 0.8809937121593899

# %%
Regressors=['Linear','Lasso','Ridge','DecisionTree','KNeighbour','SVR','RandomForest','Bayesian']
R2_Score=[linear_r2_score,lasso_r2_score,ridge_r2_score,decisiontree_r2_score,kneighbour_r2_score,svr_r2_score,randomforest_r2_score,bayes_r2_score]

# %%
plt.figure(figsize=(15,4))
plt.plot(Regressors,R2_Score, color = 'Red')

plt.title('Comparision between different Regressors',fontsize=15)
plt.xlabel('Regressors',fontsize=15)
plt.ylabel('Accuracy Values',fontsize=15)
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14456\2049796945.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## KNeighbour Regressor is sutaible for Average Temperature with accuracy of 89.72% followed by Bayesian Regressor with accuracy of 88.03%

# %%
avgtemp2020=pd.read_csv("C:/Users/HP/Downloads/Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main/Phase1/csv/AverageTemperature/avgtemp2020.csv")

# %%
avgtemp2020=avgtemp2020.drop(['Year','Month'],axis=1)

# %%
avgetemp2020=avgtemp2020.iloc[:,:].values

# %%
avgtemp2020
# Out:
#     avgtemp_past  avgtemp_pasttopast
# 0          17.27               16.97
# 1          18.52               16.52
# 2          18.47               16.26
# 3          19.05               16.79
# 4          15.40               15.34
# 5           9.39                8.35
# 6           8.10                7.48
# 7           8.78                8.12
# 8           8.60               10.91
# 9          10.03               13.51
# 10         14.19               14.70
# 11         14.96               16.18

# %%
avgtemp2020_pred=[]

# %%
#Using Kneighbour regressor for prediction
avgtemp2020_pred=kn.predict(avgtemp2020)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
avgtemp2020_pred
# Out:
# array([17.59071429, 17.07      , 17.12      , 17.35785714, 15.75785714,
#         8.80071429,  7.90285714,  8.60214286,  9.89714286, 11.55785714,
#        15.06      , 15.58428571])

# %%
#Predicting for 2020
avgtemp_data=pd.DataFrame(data=avgtemp2020_pred)
avgtemp_data
# Out:
#             0
# 0   17.590714
# 1   17.070000
# 2   17.120000
# 3   17.357857
# 4   15.757857
# 5    8.800714
# 6    7.902857
# 7    8.602143
# 8    9.897143
# 9   11.557857
# 10  15.060000
# 11  15.584286

# %%
#Exporting the predictions of 2020 into csv file
avgtemp_data.to_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\AverageTemperature\2020avgtemp.csv")
