# %%
#Importing Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import mean_squared_error,r2_score

# %%
#Importing Dataset
maxw=pd.read_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\MaxWind\MaxWind.csv")

# %%
maxw
# Out:
#      Year  Month  maxws_past  maxws_pasttopast  MaxWindSpeed
# 0    2002      1        4.07              4.99          5.08
# 1    2002      2        4.04              4.85          4.31
# 2    2002      3        5.69              4.93          5.04
# 3    2002      4        5.00              6.02          5.22
# 4    2002      5        7.74              7.13          7.42
# ..    ...    ...         ...               ...           ...
# 211  2019      8       10.20              7.80          7.80
# 212  2019      9        5.46              4.55          4.55
# 213  2019     10        4.46              3.56          3.56
# 214  2019     11        4.48              4.24          4.24
# 215  2019     12        4.64              4.96          4.96
#
# [216 rows x 5 columns]

# %%
maxw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              216 non-null    int64
#  1   Month             216 non-null    int64
#  2   maxws_past        216 non-null    float64
#  3   maxws_pasttopast  216 non-null    float64
#  4   MaxWindSpeed      216 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 8.6 KB

# %%
#Creating correlation for precipitation
#Creating the correlation matrix for the features
corr_matrix=maxw.corr()
corr_matrix
# Out:
#                           Year         Month  maxws_past  maxws_pasttopast  \
# Year              1.000000e+00  4.861859e-15   -0.026786         -0.018468
# Month             4.861859e-15  1.000000e+00    0.044938          0.029974
# maxws_past       -2.678598e-02  4.493807e-02    1.000000          0.894637
# maxws_pasttopast -1.846830e-02  2.997407e-02    0.894637          1.000000
# MaxWindSpeed     -3.019772e-02  3.917050e-02    0.898669          0.899542
#
#                   MaxWindSpeed
# Year                 -0.030198
# Month                 0.039171
# maxws_past            0.898669
# maxws_pasttopast      0.899542
# MaxWindSpeed          1.000000

# %%
mask = np.zeros_like(corr_matrix, dtype=bool)
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(5, 4)) 
heatmap = sns.heatmap(corr_matrix, mask = mask,square = True,linewidths = .5, cmap = 'coolwarm', cbar_kws = {'shrink': .4, 'ticks' : [-1, -.5, 0, 0.5, 1]},vmin = -1, vmax = 1,annot = True,annot_kws = {'size': 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
maxw=maxw.drop(['Year'],axis=1)

# %%
maxw.shape
# Out:
# (216, 4)

# %%
maxw=maxw.iloc[:,:].values

# %%
maxw
# Out:
# array([[ 1.  ,  4.07,  4.99,  5.08],
#        [ 2.  ,  4.04,  4.85,  4.31],
#        [ 3.  ,  5.69,  4.93,  5.04],
#        [ 4.  ,  5.  ,  6.02,  5.22],
#        [ 5.  ,  7.74,  7.13,  7.42],
#        [ 6.  ,  9.72,  7.76,  8.02],
#        [ 7.  , 10.02,  9.38,  9.52],
#        [ 8.  ,  8.61,  8.11,  8.96],
#        [ 9.  ,  4.46,  5.61,  5.59],
#        [10.  ,  5.28,  3.33,  4.84],
#        [11.  ,  4.82,  4.19,  4.55],
#        [12.  ,  4.68,  5.18,  4.14],
#        [ 1.  ,  5.08,  4.07,  4.72],
#        [ 2.  ,  4.31,  4.04,  4.29],
#        [ 3.  ,  5.04,  5.69,  4.65],
#        [ 4.  ,  5.22,  5.  ,  5.01],
#        [ 5.  ,  7.42,  7.74,  7.63],
#        [ 6.  ,  8.02,  9.72,  8.7 ],
#        [ 7.  ,  9.52, 10.02,  8.81],
#        [ 8.  ,  8.96,  8.61,  8.52],
#        [ 9.  ,  5.59,  4.46,  6.93],
#        [10.  ,  4.84,  5.28,  4.28],
#        [11.  ,  4.55,  4.82,  4.81],
#        [12.  ,  4.14,  4.68,  4.77],
#        [ 1.  ,  4.72,  5.08,  4.82],
#        [ 2.  ,  4.29,  4.31,  4.38],
#        [ 3.  ,  4.65,  5.04,  4.74],
#        [ 4.  ,  5.01,  5.22,  5.58],
#        [ 5.  ,  7.63,  7.42,  6.62],
#        [ 6.  ,  8.7 ,  8.02,  8.79],
#        [ 7.  ,  8.81,  9.52,  7.81],
#        [ 8.  ,  8.52,  8.96, 10.26],
#        [ 9.  ,  6.93,  5.59,  4.95],
#        [10.  ,  4.28,  4.84,  4.52],
#        [11.  ,  4.81,  4.55,  4.96],
#        [12.  ,  4.77,  4.14,  4.7 ],
#        [ 1.  ,  4.82,  4.72,  4.31],
#        [ 2.  ,  4.38,  4.29,  4.81],
#        [ 3.  ,  4.74,  4.65,  5.17],
#        [ 4.  ,  5.58,  5.01,  4.86],
#        [ 5.  ,  6.62,  7.63,  6.57],
#        [ 6.  ,  8.79,  8.7 ,  8.54],
#        [ 7.  ,  7.81,  8.81,  9.05],
#        [ 8.  , 10.26,  8.52,  8.4 ],
#        [ 9.  ,  4.95,  6.93,  6.64],
#        [10.  ,  4.52,  4.28,  4.52],
#        [11.  ,  4.96,  4.81,  5.14],
#        [12.  ,  4.7 ,  4.77,  4.22],
#        [ 1.  ,  4.31,  4.82,  4.73],
#        [ 2.  ,  4.81,  4.38,  4.61],
#        [ 3.  ,  5.17,  4.74,  5.13],
#        [ 4.  ,  4.86,  5.58,  5.61],
#        [ 5.  ,  6.57,  6.62,  6.68],
#        [ 6.  ,  8.54,  8.79,  6.96],
#        [ 7.  ,  9.05,  7.81, 11.15],
#        [ 8.  ,  8.4 , 10.26,  9.79],
#        [ 9.  ,  6.64,  4.95,  4.71],
#        [10.  ,  4.52,  4.52,  4.69],
#        [11.  ,  5.14,  4.96,  4.44],
#        [12.  ,  4.22,  4.7 ,  4.74],
#        [ 1.  ,  4.73,  4.31,  4.19],
#        [ 2.  ,  4.61,  4.81,  4.96],
#        [ 3.  ,  5.13,  5.17,  5.21],
#        [ 4.  ,  5.61,  4.86,  4.46],
#        [ 5.  ,  6.68,  6.57,  7.16],
#        [ 6.  ,  6.96,  8.54,  7.96],
#        [ 7.  , 11.15,  9.05,  8.86],
#        [ 8.  ,  9.79,  8.4 ,  8.6 ],
#        [ 9.  ,  4.71,  6.64,  6.17],
#        [10.  ,  4.69,  4.52,  4.25],
#        [11.  ,  4.44,  5.14,  4.94],
#        [12.  ,  4.74,  4.22,  4.65],
#        [ 1.  ,  4.19,  4.73,  4.65],
#        [ 2.  ,  4.96,  4.61,  4.47],
#        [ 3.  ,  5.21,  5.13,  4.3 ],
#        [ 4.  ,  4.46,  5.61,  5.09],
#        [ 5.  ,  7.16,  6.68,  7.8 ],
#        [ 6.  ,  7.96,  6.96,  9.47],
#        [ 7.  ,  8.86, 11.15,  8.81],
#        [ 8.  ,  8.6 ,  9.79,  7.71],
#        [ 9.  ,  6.17,  4.71,  5.63],
#        [10.  ,  4.25,  4.69,  4.44],
#        [11.  ,  4.94,  4.44,  5.22],
#        [12.  ,  4.65,  4.74,  4.33],
#        [ 1.  ,  4.65,  4.19,  4.9 ],
#        [ 2.  ,  4.47,  4.96,  4.01],
#        [ 3.  ,  4.3 ,  5.21,  4.57],
#        [ 4.  ,  5.09,  4.46,  5.35],
#        [ 5.  ,  7.8 ,  7.16,  6.98],
#        [ 6.  ,  9.47,  7.96,  7.72],
#        [ 7.  ,  8.81,  8.86, 11.08],
#        [ 8.  ,  7.71,  8.6 ,  7.4 ],
#        [ 9.  ,  5.63,  6.17,  4.95],
#        [10.  ,  4.44,  4.25,  4.74],
#        [11.  ,  5.22,  4.94,  5.15],
#        [12.  ,  4.33,  4.65,  4.4 ],
#        [ 1.  ,  4.9 ,  4.65,  4.71],
#        [ 2.  ,  4.01,  4.47,  4.63],
#        [ 3.  ,  4.57,  4.3 ,  4.9 ],
#        [ 4.  ,  5.35,  5.09,  5.09],
#        [ 5.  ,  6.98,  7.8 ,  7.16],
#        [ 6.  ,  7.72,  9.47,  7.16],
#        [ 7.  , 11.08,  8.81,  8.56],
#        [ 8.  ,  7.4 ,  7.71,  7.34],
#        [ 9.  ,  4.95,  5.63,  5.48],
#        [10.  ,  4.74,  4.44,  4.39],
#        [11.  ,  5.15,  5.22,  4.67],
#        [12.  ,  4.4 ,  4.33,  4.61],
#        [ 1.  ,  4.71,  4.9 ,  4.29],
#        [ 2.  ,  4.63,  4.01,  4.93],
#        [ 3.  ,  4.9 ,  4.57,  4.96],
#        [ 4.  ,  5.09,  5.35,  4.86],
#        [ 5.  ,  7.16,  6.98,  6.79],
#        [ 6.  ,  7.16,  7.72,  9.78],
#        [ 7.  ,  8.56, 11.08,  9.42],
#        [ 8.  ,  7.34,  7.4 ,  8.73],
#        [ 9.  ,  5.48,  4.95,  6.8 ],
#        [10.  ,  4.39,  4.74,  4.44],
#        [11.  ,  4.67,  5.15,  5.45],
#        [12.  ,  4.61,  4.4 ,  4.56],
#        [ 1.  ,  4.29,  4.71,  4.66],
#        [ 2.  ,  4.93,  4.63,  4.67],
#        [ 3.  ,  4.96,  4.9 ,  4.95],
#        [ 4.  ,  4.86,  5.09,  5.18],
#        [ 5.  ,  6.79,  7.16,  7.43],
#        [ 6.  ,  9.78,  7.16,  8.6 ],
#        [ 7.  ,  9.42,  8.56,  9.33],
#        [ 8.  ,  8.73,  7.34,  9.13],
#        [ 9.  ,  6.8 ,  5.48,  6.96],
#        [10.  ,  4.44,  4.39,  4.57],
#        [11.  ,  5.45,  4.67,  3.94],
#        [12.  ,  4.56,  4.61,  4.87],
#        [ 1.  ,  4.66,  4.29,  4.32],
#        [ 2.  ,  4.67,  4.93,  4.93],
#        [ 3.  ,  4.95,  4.96,  5.16],
#        [ 4.  ,  5.18,  4.86,  6.13],
#        [ 5.  ,  7.43,  6.79,  7.52],
#        [ 6.  ,  8.6 ,  9.78,  9.08],
#        [ 7.  ,  9.33,  9.42, 10.62],
#        [ 8.  ,  9.13,  8.73,  8.28],
#        [ 9.  ,  6.96,  6.8 ,  5.72],
#        [10.  ,  4.57,  4.44,  4.87],
#        [11.  ,  3.94,  5.45,  4.76],
#        [12.  ,  4.87,  4.56,  4.76],
#        [ 1.  ,  4.32,  4.66,  5.52],
#        [ 2.  ,  4.93,  4.67,  5.33],
#        [ 3.  ,  5.16,  4.95,  5.07],
#        [ 4.  ,  6.13,  5.18,  4.81],
#        [ 5.  ,  7.52,  7.43,  5.87],
#        [ 6.  ,  9.08,  8.6 ,  8.66],
#        [ 7.  , 10.62,  9.33, 10.18],
#        [ 8.  ,  8.28,  9.13,  7.37],
#        [ 9.  ,  5.72,  6.96,  6.37],
#        [10.  ,  4.87,  4.57,  4.32],
#        [11.  ,  4.76,  3.94,  4.62],
#        [12.  ,  4.76,  4.87,  4.47],
#        [ 1.  ,  5.52,  4.32,  4.68],
#        [ 2.  ,  5.33,  4.93,  4.9 ],
#        [ 3.  ,  5.07,  5.16,  5.07],
#        [ 4.  ,  4.81,  6.13,  5.06],
#        [ 5.  ,  5.87,  7.52,  6.2 ],
#        [ 6.  ,  8.66,  9.08,  8.44],
#        [ 7.  , 10.18, 10.62,  9.56],
#        [ 8.  ,  7.37,  8.28,  7.36],
#        [ 9.  ,  6.37,  5.72,  4.88],
#        [10.  ,  4.32,  4.87,  4.07],
#        [11.  ,  4.62,  4.76,  5.26],
#        [12.  ,  4.47,  4.76,  4.62],
#        [ 1.  ,  4.68,  5.52,  4.31],
#        [ 2.  ,  4.9 ,  5.33,  4.62],
#        [ 3.  ,  5.07,  5.07,  4.75],
#        [ 4.  ,  5.06,  4.81,  5.67],
#        [ 5.  ,  6.2 ,  5.87,  6.94],
#        [ 6.  ,  8.44,  8.66,  7.76],
#        [ 7.  ,  9.56, 10.18,  8.58],
#        [ 8.  ,  7.36,  7.37,  9.04],
#        [ 9.  ,  4.88,  6.37,  6.39],
#        [10.  ,  4.07,  4.32,  4.05],
#        [11.  ,  5.26,  4.62,  4.3 ],
#        [12.  ,  4.62,  4.47,  4.38],
#        [ 1.  ,  4.31,  4.68,  4.31],
#        [ 2.  ,  4.62,  4.9 ,  4.87],
#        [ 3.  ,  4.75,  5.07,  4.72],
#        [ 4.  ,  5.67,  5.06,  5.68],
#        [ 5.  ,  6.94,  6.2 ,  6.48],
#        [ 6.  ,  7.76,  8.44,  7.78],
#        [ 7.  ,  8.58,  9.56, 10.36],
#        [ 8.  ,  9.04,  7.36,  7.8 ],
#        [ 9.  ,  6.39,  4.88,  4.55],
#        [10.  ,  4.05,  4.07,  3.56],
#        [11.  ,  4.3 ,  5.26,  4.24],
#        [12.  ,  4.38,  4.62,  4.96],
#        [ 1.  ,  4.31,  4.31,  3.93],
#        [ 2.  ,  4.87,  4.62,  4.11],
#        [ 3.  ,  4.72,  4.75,  4.21],
#        [ 4.  ,  5.68,  5.67,  4.89],
#        [ 5.  ,  6.48,  6.94,  6.16],
#        [ 6.  ,  7.78,  7.76,  7.88],
#        [ 7.  , 10.36,  8.58, 10.57],
#        [ 8.  ,  7.8 ,  9.04, 10.2 ],
#        [ 9.  ,  4.55,  6.39,  5.46],
#        [10.  ,  3.56,  4.05,  4.46],
#        [11.  ,  4.24,  4.3 ,  4.48],
#        [12.  ,  4.96,  4.38,  4.64],
#        [ 1.  ,  3.93,  4.31,  4.31],
#        [ 2.  ,  4.11,  4.87,  4.87],
#        [ 3.  ,  4.21,  4.72,  4.72],
#        [ 4.  ,  4.89,  5.68,  5.68],
#        [ 5.  ,  6.16,  6.48,  6.48],
#        [ 6.  ,  7.88,  7.78,  7.78],
#        [ 7.  , 10.57, 10.36, 10.36],
#        [ 8.  , 10.2 ,  7.8 ,  7.8 ],
#        [ 9.  ,  5.46,  4.55,  4.55],
#        [10.  ,  4.46,  3.56,  3.56],
#        [11.  ,  4.48,  4.24,  4.24],
#        [12.  ,  4.64,  4.96,  4.96]])

# %%
X=maxw[:,:-1]
y=maxw[:,-1]

# %%
X
# Out:
# array([[ 1.  ,  4.07,  4.99],
#        [ 2.  ,  4.04,  4.85],
#        [ 3.  ,  5.69,  4.93],
#        [ 4.  ,  5.  ,  6.02],
#        [ 5.  ,  7.74,  7.13],
#        [ 6.  ,  9.72,  7.76],
#        [ 7.  , 10.02,  9.38],
#        [ 8.  ,  8.61,  8.11],
#        [ 9.  ,  4.46,  5.61],
#        [10.  ,  5.28,  3.33],
#        [11.  ,  4.82,  4.19],
#        [12.  ,  4.68,  5.18],
#        [ 1.  ,  5.08,  4.07],
#        [ 2.  ,  4.31,  4.04],
#        [ 3.  ,  5.04,  5.69],
#        [ 4.  ,  5.22,  5.  ],
#        [ 5.  ,  7.42,  7.74],
#        [ 6.  ,  8.02,  9.72],
#        [ 7.  ,  9.52, 10.02],
#        [ 8.  ,  8.96,  8.61],
#        [ 9.  ,  5.59,  4.46],
#        [10.  ,  4.84,  5.28],
#        [11.  ,  4.55,  4.82],
#        [12.  ,  4.14,  4.68],
#        [ 1.  ,  4.72,  5.08],
#        [ 2.  ,  4.29,  4.31],
#        [ 3.  ,  4.65,  5.04],
#        [ 4.  ,  5.01,  5.22],
#        [ 5.  ,  7.63,  7.42],
#        [ 6.  ,  8.7 ,  8.02],
#        [ 7.  ,  8.81,  9.52],
#        [ 8.  ,  8.52,  8.96],
#        [ 9.  ,  6.93,  5.59],
#        [10.  ,  4.28,  4.84],
#        [11.  ,  4.81,  4.55],
#        [12.  ,  4.77,  4.14],
#        [ 1.  ,  4.82,  4.72],
#        [ 2.  ,  4.38,  4.29],
#        [ 3.  ,  4.74,  4.65],
#        [ 4.  ,  5.58,  5.01],
#        [ 5.  ,  6.62,  7.63],
#        [ 6.  ,  8.79,  8.7 ],
#        [ 7.  ,  7.81,  8.81],
#        [ 8.  , 10.26,  8.52],
#        [ 9.  ,  4.95,  6.93],
#        [10.  ,  4.52,  4.28],
#        [11.  ,  4.96,  4.81],
#        [12.  ,  4.7 ,  4.77],
#        [ 1.  ,  4.31,  4.82],
#        [ 2.  ,  4.81,  4.38],
#        [ 3.  ,  5.17,  4.74],
#        [ 4.  ,  4.86,  5.58],
#        [ 5.  ,  6.57,  6.62],
#        [ 6.  ,  8.54,  8.79],
#        [ 7.  ,  9.05,  7.81],
#        [ 8.  ,  8.4 , 10.26],
#        [ 9.  ,  6.64,  4.95],
#        [10.  ,  4.52,  4.52],
#        [11.  ,  5.14,  4.96],
#        [12.  ,  4.22,  4.7 ],
#        [ 1.  ,  4.73,  4.31],
#        [ 2.  ,  4.61,  4.81],
#        [ 3.  ,  5.13,  5.17],
#        [ 4.  ,  5.61,  4.86],
#        [ 5.  ,  6.68,  6.57],
#        [ 6.  ,  6.96,  8.54],
#        [ 7.  , 11.15,  9.05],
#        [ 8.  ,  9.79,  8.4 ],
#        [ 9.  ,  4.71,  6.64],
#        [10.  ,  4.69,  4.52],
#        [11.  ,  4.44,  5.14],
#        [12.  ,  4.74,  4.22],
#        [ 1.  ,  4.19,  4.73],
#        [ 2.  ,  4.96,  4.61],
#        [ 3.  ,  5.21,  5.13],
#        [ 4.  ,  4.46,  5.61],
#        [ 5.  ,  7.16,  6.68],
#        [ 6.  ,  7.96,  6.96],
#        [ 7.  ,  8.86, 11.15],
#        [ 8.  ,  8.6 ,  9.79],
#        [ 9.  ,  6.17,  4.71],
#        [10.  ,  4.25,  4.69],
#        [11.  ,  4.94,  4.44],
#        [12.  ,  4.65,  4.74],
#        [ 1.  ,  4.65,  4.19],
#        [ 2.  ,  4.47,  4.96],
#        [ 3.  ,  4.3 ,  5.21],
#        [ 4.  ,  5.09,  4.46],
#        [ 5.  ,  7.8 ,  7.16],
#        [ 6.  ,  9.47,  7.96],
#        [ 7.  ,  8.81,  8.86],
#        [ 8.  ,  7.71,  8.6 ],
#        [ 9.  ,  5.63,  6.17],
#        [10.  ,  4.44,  4.25],
#        [11.  ,  5.22,  4.94],
#        [12.  ,  4.33,  4.65],
#        [ 1.  ,  4.9 ,  4.65],
#        [ 2.  ,  4.01,  4.47],
#        [ 3.  ,  4.57,  4.3 ],
#        [ 4.  ,  5.35,  5.09],
#        [ 5.  ,  6.98,  7.8 ],
#        [ 6.  ,  7.72,  9.47],
#        [ 7.  , 11.08,  8.81],
#        [ 8.  ,  7.4 ,  7.71],
#        [ 9.  ,  4.95,  5.63],
#        [10.  ,  4.74,  4.44],
#        [11.  ,  5.15,  5.22],
#        [12.  ,  4.4 ,  4.33],
#        [ 1.  ,  4.71,  4.9 ],
#        [ 2.  ,  4.63,  4.01],
#        [ 3.  ,  4.9 ,  4.57],
#        [ 4.  ,  5.09,  5.35],
#        [ 5.  ,  7.16,  6.98],
#        [ 6.  ,  7.16,  7.72],
#        [ 7.  ,  8.56, 11.08],
#        [ 8.  ,  7.34,  7.4 ],
#        [ 9.  ,  5.48,  4.95],
#        [10.  ,  4.39,  4.74],
#        [11.  ,  4.67,  5.15],
#        [12.  ,  4.61,  4.4 ],
#        [ 1.  ,  4.29,  4.71],
#        [ 2.  ,  4.93,  4.63],
#        [ 3.  ,  4.96,  4.9 ],
#        [ 4.  ,  4.86,  5.09],
#        [ 5.  ,  6.79,  7.16],
#        [ 6.  ,  9.78,  7.16],
#        [ 7.  ,  9.42,  8.56],
#        [ 8.  ,  8.73,  7.34],
#        [ 9.  ,  6.8 ,  5.48],
#        [10.  ,  4.44,  4.39],
#        [11.  ,  5.45,  4.67],
#        [12.  ,  4.56,  4.61],
#        [ 1.  ,  4.66,  4.29],
#        [ 2.  ,  4.67,  4.93],
#        [ 3.  ,  4.95,  4.96],
#        [ 4.  ,  5.18,  4.86],
#        [ 5.  ,  7.43,  6.79],
#        [ 6.  ,  8.6 ,  9.78],
#        [ 7.  ,  9.33,  9.42],
#        [ 8.  ,  9.13,  8.73],
#        [ 9.  ,  6.96,  6.8 ],
#        [10.  ,  4.57,  4.44],
#        [11.  ,  3.94,  5.45],
#        [12.  ,  4.87,  4.56],
#        [ 1.  ,  4.32,  4.66],
#        [ 2.  ,  4.93,  4.67],
#        [ 3.  ,  5.16,  4.95],
#        [ 4.  ,  6.13,  5.18],
#        [ 5.  ,  7.52,  7.43],
#        [ 6.  ,  9.08,  8.6 ],
#        [ 7.  , 10.62,  9.33],
#        [ 8.  ,  8.28,  9.13],
#        [ 9.  ,  5.72,  6.96],
#        [10.  ,  4.87,  4.57],
#        [11.  ,  4.76,  3.94],
#        [12.  ,  4.76,  4.87],
#        [ 1.  ,  5.52,  4.32],
#        [ 2.  ,  5.33,  4.93],
#        [ 3.  ,  5.07,  5.16],
#        [ 4.  ,  4.81,  6.13],
#        [ 5.  ,  5.87,  7.52],
#        [ 6.  ,  8.66,  9.08],
#        [ 7.  , 10.18, 10.62],
#        [ 8.  ,  7.37,  8.28],
#        [ 9.  ,  6.37,  5.72],
#        [10.  ,  4.32,  4.87],
#        [11.  ,  4.62,  4.76],
#        [12.  ,  4.47,  4.76],
#        [ 1.  ,  4.68,  5.52],
#        [ 2.  ,  4.9 ,  5.33],
#        [ 3.  ,  5.07,  5.07],
#        [ 4.  ,  5.06,  4.81],
#        [ 5.  ,  6.2 ,  5.87],
#        [ 6.  ,  8.44,  8.66],
#        [ 7.  ,  9.56, 10.18],
#        [ 8.  ,  7.36,  7.37],
#        [ 9.  ,  4.88,  6.37],
#        [10.  ,  4.07,  4.32],
#        [11.  ,  5.26,  4.62],
#        [12.  ,  4.62,  4.47],
#        [ 1.  ,  4.31,  4.68],
#        [ 2.  ,  4.62,  4.9 ],
#        [ 3.  ,  4.75,  5.07],
#        [ 4.  ,  5.67,  5.06],
#        [ 5.  ,  6.94,  6.2 ],
#        [ 6.  ,  7.76,  8.44],
#        [ 7.  ,  8.58,  9.56],
#        [ 8.  ,  9.04,  7.36],
#        [ 9.  ,  6.39,  4.88],
#        [10.  ,  4.05,  4.07],
#        [11.  ,  4.3 ,  5.26],
#        [12.  ,  4.38,  4.62],
#        [ 1.  ,  4.31,  4.31],
#        [ 2.  ,  4.87,  4.62],
#        [ 3.  ,  4.72,  4.75],
#        [ 4.  ,  5.68,  5.67],
#        [ 5.  ,  6.48,  6.94],
#        [ 6.  ,  7.78,  7.76],
#        [ 7.  , 10.36,  8.58],
#        [ 8.  ,  7.8 ,  9.04],
#        [ 9.  ,  4.55,  6.39],
#        [10.  ,  3.56,  4.05],
#        [11.  ,  4.24,  4.3 ],
#        [12.  ,  4.96,  4.38],
#        [ 1.  ,  3.93,  4.31],
#        [ 2.  ,  4.11,  4.87],
#        [ 3.  ,  4.21,  4.72],
#        [ 4.  ,  4.89,  5.68],
#        [ 5.  ,  6.16,  6.48],
#        [ 6.  ,  7.88,  7.78],
#        [ 7.  , 10.57, 10.36],
#        [ 8.  , 10.2 ,  7.8 ],
#        [ 9.  ,  5.46,  4.55],
#        [10.  ,  4.46,  3.56],
#        [11.  ,  4.48,  4.24],
#        [12.  ,  4.64,  4.96]])

# %%
y
# Out:
# array([ 5.08,  4.31,  5.04,  5.22,  7.42,  8.02,  9.52,  8.96,  5.59,
#         4.84,  4.55,  4.14,  4.72,  4.29,  4.65,  5.01,  7.63,  8.7 ,
#         8.81,  8.52,  6.93,  4.28,  4.81,  4.77,  4.82,  4.38,  4.74,
#         5.58,  6.62,  8.79,  7.81, 10.26,  4.95,  4.52,  4.96,  4.7 ,
#         4.31,  4.81,  5.17,  4.86,  6.57,  8.54,  9.05,  8.4 ,  6.64,
#         4.52,  5.14,  4.22,  4.73,  4.61,  5.13,  5.61,  6.68,  6.96,
#        11.15,  9.79,  4.71,  4.69,  4.44,  4.74,  4.19,  4.96,  5.21,
#         4.46,  7.16,  7.96,  8.86,  8.6 ,  6.17,  4.25,  4.94,  4.65,
#         4.65,  4.47,  4.3 ,  5.09,  7.8 ,  9.47,  8.81,  7.71,  5.63,
#         4.44,  5.22,  4.33,  4.9 ,  4.01,  4.57,  5.35,  6.98,  7.72,
#        11.08,  7.4 ,  4.95,  4.74,  5.15,  4.4 ,  4.71,  4.63,  4.9 ,
#         5.09,  7.16,  7.16,  8.56,  7.34,  5.48,  4.39,  4.67,  4.61,
#         4.29,  4.93,  4.96,  4.86,  6.79,  9.78,  9.42,  8.73,  6.8 ,
#         4.44,  5.45,  4.56,  4.66,  4.67,  4.95,  5.18,  7.43,  8.6 ,
#         9.33,  9.13,  6.96,  4.57,  3.94,  4.87,  4.32,  4.93,  5.16,
#         6.13,  7.52,  9.08, 10.62,  8.28,  5.72,  4.87,  4.76,  4.76,
#         5.52,  5.33,  5.07,  4.81,  5.87,  8.66, 10.18,  7.37,  6.37,
#         4.32,  4.62,  4.47,  4.68,  4.9 ,  5.07,  5.06,  6.2 ,  8.44,
#         9.56,  7.36,  4.88,  4.07,  5.26,  4.62,  4.31,  4.62,  4.75,
#         5.67,  6.94,  7.76,  8.58,  9.04,  6.39,  4.05,  4.3 ,  4.38,
#         4.31,  4.87,  4.72,  5.68,  6.48,  7.78, 10.36,  7.8 ,  4.55,
#         3.56,  4.24,  4.96,  3.93,  4.11,  4.21,  4.89,  6.16,  7.88,
#        10.57, 10.2 ,  5.46,  4.46,  4.48,  4.64,  4.31,  4.87,  4.72,
#         5.68,  6.48,  7.78, 10.36,  7.8 ,  4.55,  3.56,  4.24,  4.96])

# %%
X.shape
# Out:
# (216, 3)

# %%
y.shape
# Out:
# (216,)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
X_train,y_train=np.array(X_train),np.array(y_train)

# %% [markdown]
# ### Linear Regressor

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
li=LinearRegression()

# %%
li.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Lir_ypred= li.predict(X_test)
Lir_ypred
# Out:
# array([4.89981724, 9.88168548, 4.64999272, 4.83397693, 4.42969057,
#        4.46705097, 5.20221526, 9.01154053, 8.80108676, 5.71511383,
#        4.82005969, 8.51979788, 4.1937135 , 4.84453581, 8.63362414,
#        4.84075134, 5.00673531, 7.3532495 , 7.95797963, 7.37987525,
#        4.62441728, 7.54608   , 5.10546811, 4.60838451, 8.53779895,
#        4.94452641, 5.01632942, 4.78518866, 5.58593976, 4.70795694,
#        4.63695311, 5.14429225, 9.43677593, 4.42245671, 4.38552396,
#        8.72999433, 8.29482974, 5.35953647, 4.67841891, 4.86153015,
#        5.04207832, 4.76865844, 4.70669754, 5.34191243])

# %%
#print('Mean Absolute Error:',mean_absolute_error(y_test,Lir_ypred))
print('Mean squared Error:',mean_squared_error(y_test,Lir_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lir_ypred)))
#print('R2_Score:',r2_score(y_test,Lir_ypred))
# Out:
# Mean squared Error: 0.5555235711777299
# Root Mean Squared Error: 0.7453345364181978

# %%
linear_r2_score=r2_score(y_test,Lir_ypred)
linear_r2_score
# Out:
# 0.8638301945764613

# %% [markdown]
# ### Lasso Regressor

# %%
#Lasso Regressor
lass=Lasso(alpha=0.0001)
lass.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
Lass_ypred= lass.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,Lass_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lass_ypred)))
print('R2_Score:',r2_score(y_test,Lass_ypred))
# Out:
# Mean squared Error: 0.5555599653111594
# Root Mean Squared Error: 0.745358950648048
# R2_Score: 0.8638212736551453

# %%
lasso_r2_score=r2_score(y_test,Lass_ypred)
lasso_r2_score
# Out:
# 0.8638212736551453

# %% [markdown]
# ### Ridge Regressor

# %%
#RIdge
rid=Ridge(alpha=0.0001)
rid.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
rid_ypred= rid.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,rid_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rid_ypred)))
#print('R2_Score:',r2_score(y_test,rid_ypred))
# Out:
# Mean squared Error: 0.5555236092475054
# Root Mean Squared Error: 0.7453345619569144

# %%
ridge_r2_score=r2_score(y_test,rid_ypred)
ridge_r2_score
# Out:
# 0.8638301852448069

# %% [markdown]
# ### Decision Tree Regressor

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_ypred= dt.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,dt_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dt_ypred)))
#print('R2_Score:',r2_score(y_test,dt_ypred))
# Out:
# Mean squared Error: 1.4394749999999998
# Root Mean Squared Error: 1.1997812300582136

# %%
decisiontree_r2_score=r2_score(y_test,dt_ypred)
decisiontree_r2_score
# Out:
# 0.6471562309291508

# %% [markdown]
# ### KNeighbour Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn=KNeighborsRegressor(n_neighbors=10)
kn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
kn1_pred=kn.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,kn1_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,kn1_pred)))
#print('R2_Score:',r2_score(y_test,kn1_pred))
# Out:
# Mean squared Error: 0.45421668181818187
# Root Mean Squared Error: 0.6739559939774865

# %%
kneighbour_r2_score=r2_score(y_test,kn1_pred)
kneighbour_r2_score
# Out:
# 0.8886625151617208

# %% [markdown]
# ### SVR Regressor

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf')
svr.fit(X_train,y_train)
svr_pred=svr.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,svr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,svr_pred)))
#print('R2_Score:',r2_score(y_test,svr_pred))
# Out:
# Mean squared Error: 0.5537830912075483
# Root Mean Squared Error: 0.7441660373918904

# %%
svr_r2_score=r2_score(y_test,svr_pred)
svr_r2_score
# Out:
# 0.864256820612114

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train);

# %%
rf_pred=rf.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,rf_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rf_pred)))
print('R2_Score:',r2_score(y_test,rf_pred))
# Out:
# Mean squared Error: 0.6799619984931865
# Root Mean Squared Error: 0.8245980830035845
# R2_Score: 0.8333278769181243

# %%
randomforest_r2_score=r2_score(y_test,rf_pred)
randomforest_r2_score
# Out:
# 0.8333278769181243

# %% [markdown]
# ### Bayesian Regressor

# %%
from sklearn.linear_model import BayesianRidge
br=BayesianRidge()
br.fit(X_train,y_train)
y_pred=br.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred)))
#print('R2_Score:',r2_score(y_test,y_pred))
# Out:
# Mean squared Error: 0.556871946150136
# Root Mean Squared Error: 0.7462385316707628

# %%
bayesian_r2_score=r2_score(y_test,y_pred)
bayesian_r2_score
# Out:
# 0.8634996812244513

# %%
Regressors=['Linear','Lasso','Ridge','DecisionTree','KNeighbour','SVR','RandomForest','Bayesian']
R2_Score=[linear_r2_score,lasso_r2_score,ridge_r2_score,decisiontree_r2_score,kneighbour_r2_score,svr_r2_score,randomforest_r2_score,bayesian_r2_score]

# %%
plt.figure(figsize=(15,4))
plt.plot(Regressors,R2_Score, color = 'Red')

plt.title('Comparision between different Regressors',fontsize=15)
plt.xlabel('Regressors',fontsize=15)
plt.ylabel('Accuracy Values',fontsize=15)
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21496\2049796945.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # KNeighbour is best for Max Wind  with accuracy of 88.886% followed by Bayesian Rgressor with 86.3%

# %%
maxw2020=pd.read_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\MaxWind\maxwind2020pred.csv")

# %%
maxw2020.drop(['Year'],axis=1,inplace=True)

# %%
maxw2020=maxw2020.iloc[:,:].values

# %%
maxw2020
# Out:
# array([[ 1.  ,  4.31,  3.93],
#        [ 2.  ,  4.87,  4.11],
#        [ 3.  ,  4.72,  4.21],
#        [ 4.  ,  5.68,  4.89],
#        [ 5.  ,  6.48,  6.16],
#        [ 6.  ,  7.78,  7.88],
#        [ 7.  , 10.36, 10.57],
#        [ 8.  ,  7.8 , 10.2 ],
#        [ 9.  ,  4.55,  5.46],
#        [10.  ,  3.56,  4.46],
#        [11.  ,  4.24,  4.48],
#        [12.  ,  4.96,  4.64]])

# %%
maxw2020_pred=[]

# %%
maxw2020_pred=kn.predict(maxw2020)

# %%
maxw2020_pred
# Out:
# array([4.51 , 4.575, 4.863, 5.264, 6.944, 8.045, 9.281, 8.853, 5.193,
#        4.454, 4.814, 4.647])

# %%
maxwind_data=pd.DataFrame(data=maxw2020_pred)
maxwind_data
# Out:
#         0
# 0   4.510
# 1   4.575
# 2   4.863
# 3   5.264
# 4   6.944
# 5   8.045
# 6   9.281
# 7   8.853
# 8   5.193
# 9   4.454
# 10  4.814
# 11  4.647

# %%
maxwind_data.to_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\MaxWind\2020maxwind.csv")
