# %%
#Importing Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import mean_squared_error,r2_score

# %%
#Importing the dataset
sp=pd.read_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\SurfacePressure\surfacepressure.csv")

# %%
sp
# Out:
#      Year  Month  sp_past  sp_pasttopast  surfacepressure
# 0    2002      1    94.28          94.34            94.40
# 1    2002      2    94.20          94.16            94.45
# 2    2002      3    94.11          94.10            94.14
# 3    2002      4    94.00          93.86            93.94
# 4    2002      5    93.80          93.82            93.82
# ..    ...    ...      ...            ...              ...
# 211  2019      8    93.78          93.75            93.75
# 212  2019      9    94.07          93.94            93.94
# 213  2019     10    94.28          94.08            94.08
# 214  2019     11    94.41          94.31            94.31
# 215  2019     12    94.47          94.44            94.44
#
# [216 rows x 5 columns]

# %%
sp.shape
# Out:
# (216, 5)

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             216 non-null    int64
#  1   Month            216 non-null    int64
#  2   sp_past          216 non-null    float64
#  3   sp_pasttopast    216 non-null    float64
#  4   surfacepressure  216 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 8.6 KB

# %%
#Creating correlation matrix for precipitation
corr_matrix=sp.corr()
corr_matrix
# Out:
#                          Year         Month   sp_past  sp_pasttopast  \
# Year             1.000000e+00  4.861859e-15  0.040462       0.055817
# Month            4.861859e-15  1.000000e+00 -0.016185      -0.018275
# sp_past          4.046209e-02 -1.618506e-02  1.000000       0.943674
# sp_pasttopast    5.581654e-02 -1.827503e-02  0.943674       1.000000
# surfacepressure  3.688419e-02 -3.334479e-02  0.942742       0.942395
#
#                  surfacepressure
# Year                    0.036884
# Month                  -0.033345
# sp_past                 0.942742
# sp_pasttopast           0.942395
# surfacepressure         1.000000

# %%
mask = np.zeros_like(corr_matrix, dtype=bool)
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(5, 4)) 
heatmap = sns.heatmap(corr_matrix, mask = mask,square = True,linewidths = .5, cmap = 'coolwarm', cbar_kws = {'shrink': .4, 'ticks' : [-1, -.5, 0, 0.5, 1]},vmin = -1, vmax = 1,annot = True,annot_kws = {'size': 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
sp=sp.drop(['Month'],axis=1)

# %%
sp.shape
# Out:
# (216, 4)

# %%
X=sp.drop('surfacepressure',axis=1)
y=sp.surfacepressure

# %%
X
# Out:
#      Year  sp_past  sp_pasttopast
# 0    2002    94.28          94.34
# 1    2002    94.20          94.16
# 2    2002    94.11          94.10
# 3    2002    94.00          93.86
# 4    2002    93.80          93.82
# ..    ...      ...            ...
# 211  2019    93.78          93.75
# 212  2019    94.07          93.94
# 213  2019    94.28          94.08
# 214  2019    94.41          94.31
# 215  2019    94.47          94.44
#
# [216 rows x 3 columns]

# %%
y
# Out:
# 0      94.40
# 1      94.45
# 2      94.14
# 3      93.94
# 4      93.82
#        ...
# 211    93.75
# 212    93.94
# 213    94.08
# 214    94.31
# 215    94.44
# Name: surfacepressure, Length: 216, dtype: float64

# %%
X.shape
# Out:
# (216, 3)

# %%
y.shape
# Out:
# (216,)

# %%
#Creating Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
X_train,y_train=np.array(X_train),np.array(y_train)

# %% [markdown]
# ### Linear Regressor

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
li=LinearRegression()

# %%
li.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction of values
Lir_ypred= li.predict(X_test)
Lir_ypred
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([94.34110347, 93.68165416, 94.07812043, 94.37940323, 94.28442377,
#        94.16279862, 94.13854614, 93.80454618, 93.77916608, 93.97697848,
#        94.14056347, 93.79517737, 94.22515572, 94.25861955, 93.66967373,
#        94.20338238, 94.42573212, 93.83595499, 93.72924992, 93.87032802,
#        94.29838512, 93.66011107, 94.01273943, 94.34003682, 93.71688178,
#        94.29190137, 94.18621471, 94.35524176, 93.99701936, 94.2250296 ,
#        94.11889933, 94.22852585, 93.64062172, 94.31305166, 94.35190803,
#        93.72098417, 93.69562864, 94.10528253, 94.32795354, 94.2428034 ,
#        94.35775601, 94.33978836, 94.39721344, 93.99661345])

# %%
#print('Mean Absolute Error:',mean_absolute_error(y_test,Lir_ypred))
print('Mean squared Error:',mean_squared_error(y_test,Lir_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lir_ypred)))
#print('R2_Score:',r2_score(y_test,Lir_ypred))
# Out:
# Mean squared Error: 0.008807452361926637
# Root Mean Squared Error: 0.0938480280129883

# %%
linear_r2_score=r2_score(y_test,Lir_ypred)
linear_r2_score
# Out:
# 0.9011822631591128

# %% [markdown]
# ### Lasso Regressor

# %%
#Lasso Regressor
lass=Lasso(alpha=0.0001)
lass.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
Lass_ypred= lass.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but Lasso was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,Lass_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lass_ypred)))
#print('R2_Score:',r2_score(y_test,Lass_ypred))
# Out:
# Mean squared Error: 0.008833115817287369
# Root Mean Squared Error: 0.09398465735048124

# %%
lasso_r2_score=r2_score(y_test,Lass_ypred)
lasso_r2_score
# Out:
# 0.9008943246640688

# %% [markdown]
# ### Ridge Regressor

# %%
#RIdge
rid=Ridge(alpha=0.0001)
rid.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
rid_ypred= rid.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but Ridge was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,rid_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rid_ypred)))
#print('R2_Score:',r2_score(y_test,rid_ypred))
# Out:
# Mean squared Error: 0.008807517860510435
# Root Mean Squared Error: 0.09384837697323505

# %%
ridge_r2_score=r2_score(y_test,rid_ypred)
ridge_r2_score
# Out:
# 0.9011815282789736

# %% [markdown]
# ### Decision Tree Regressor

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_ypred= dt.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,dt_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dt_ypred)))
#print('R2_Score:',r2_score(y_test,dt_ypred))
# Out:
# Mean squared Error: 0.016099999999999982
# Root Mean Squared Error: 0.12688577540449514

# %%
decisiontree_r2_score=r2_score(y_test,dt_ypred)
decisiontree_r2_score
# Out:
# 0.8193614341854631

# %% [markdown]
# ### KNeighbour Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn=KNeighborsRegressor(n_neighbors=2)
kn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
kn1_pred=kn.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,kn1_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,kn1_pred)))
#print('R2_Score:',r2_score(y_test,kn1_pred))
# Out:
# Mean squared Error: 0.019273295454545123
# Root Mean Squared Error: 0.13882829486291734

# %%
kneighbour_r2_score=r2_score(y_test,kn1_pred)
kneighbour_r2_score
# Out:
# 0.7837577360603188

# %% [markdown]
# ### SVR Regressor

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf')
svr.fit(X_train,y_train)
svr_pred=svr.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVR was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,svr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,svr_pred)))
#print('R2_Score:',r2_score(y_test,svr_pred))
# Out:
# Mean squared Error: 0.09148292678524847
# Root Mean Squared Error: 0.3024614467750369

# %%
svr_r2_score=r2_score(y_test,svr_pred)
svr_r2_score
# Out:
# -0.026418924907054553

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 42)
rf.fit(X_train, y_train);

# %%
rf_pred=rf.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,rf_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rf_pred)))
#print('R2_Score:',r2_score(y_test,rf_pred))
# Out:
# Mean squared Error: 0.011214384090909427
# Root Mean Squared Error: 0.10589798907868565

# %%
randomforest_r2_score=r2_score(y_test,rf_pred)
randomforest_r2_score
# Out:
# 0.8741770025667553

# %% [markdown]
# ### Bayes Regressor

# %%
from sklearn.linear_model import BayesianRidge
br=BayesianRidge()
br.fit(X_train,y_train)
# Out:
# BayesianRidge()

# %%
br_pred=br.predict(X_test)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but BayesianRidge was fitted without feature names
#   warnings.warn(

# %%
print('Mean squared Error:',mean_squared_error(y_test,br_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,br_pred)))
print('R2_Score:',r2_score(y_test,br_pred))
# Out:
# Mean squared Error: 0.00883694955016618
# Root Mean Squared Error: 0.09400505066306905
# R2_Score: 0.9008513109989169

# %%
bayes_r2_score=r2_score(y_test,br_pred)
bayes_r2_score
# Out:
# 0.9008513109989169

# %%
Regressors=['Linear','Lasso','Ridge','DecisionTree','KNeighbour','SVR','RandomForest','Bayesian']
R2_Score=[linear_r2_score,lasso_r2_score,ridge_r2_score,decisiontree_r2_score,kneighbour_r2_score,svr_r2_score,randomforest_r2_score,bayes_r2_score]

# %%
plt.figure(figsize=(15,4))
plt.plot(Regressors,R2_Score, color = 'Red')

plt.title('Comparision between different Regressors',fontsize=15)
plt.xlabel('Regressors',fontsize=15)
plt.ylabel('Accuracy Values',fontsize=15)
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25908\2049796945.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Linear Regressor is sutaible for Surface Pressure with accuracy of 90.11% followed by Ridge Regressor with accuracy of 90%

# %%
sp2020=pd.read_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\SurfacePressure\surfacepressure2020.csv")

# %%
sp2020=sp2020.drop(['Month'],axis=1)

# %%
sp2020=sp2020.iloc[:,:].values

# %%
sp2020
# Out:
# array([[2020.  ,   94.47,   94.35],
#        [2020.  ,   94.44,   94.39],
#        [2020.  ,   94.16,   94.18],
#        [2020.  ,   94.03,   94.  ],
#        [2020.  ,   93.89,   93.83],
#        [2020.  ,   93.73,   93.66],
#        [2020.  ,   93.75,   93.64],
#        [2020.  ,   93.75,   93.78],
#        [2020.  ,   93.94,   94.07],
#        [2020.  ,   94.08,   94.28],
#        [2020.  ,   94.31,   94.41],
#        [2020.  ,   94.44,   94.47]])

# %%
sp2020_pred=[]

# %%
#Using Kneighbour regressor for prediction
sp2020_pred=li.predict(sp2020)

# %%
sp2020_pred
# Out:
# array([94.39348056, 94.39712243, 94.16563414, 94.0206111 , 93.875285  ,
#        93.72025063, 93.72085676, 93.78457174, 94.00878137, 94.17231175,
#        94.3431208 , 94.43353099])

# %%
sp_data=pd.DataFrame(data=sp2020_pred)
sp_data
# Out:
#             0
# 0   94.393481
# 1   94.397122
# 2   94.165634
# 3   94.020611
# 4   93.875285
# 5   93.720251
# 6   93.720857
# 7   93.784572
# 8   94.008781
# 9   94.172312
# 10  94.343121
# 11  94.433531

# %%
#Exporting the predictions of 2020 into csv file
sp_data.to_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\SurfacePressure\2020surfacepressure.csv")
