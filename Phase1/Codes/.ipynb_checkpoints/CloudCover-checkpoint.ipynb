# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cc=pd.read_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\cloudcover\cloudcover.csv")

# %%
cc
# Out:
#      Year  Month  cc_past  cc_pasttopast  Cloud Coverage
# 0    2002      1     0.66           0.69            0.69
# 1    2002      2     0.71           0.68            0.66
# 2    2002      3     0.71           0.70            0.68
# 3    2002      4     0.62           0.67            0.63
# 4    2002      5     0.62           0.57            0.62
# ..    ...    ...      ...            ...             ...
# 211  2019      8     0.38           0.38            0.38
# 212  2019      9     0.44           0.44            0.44
# 213  2019     10     0.53           0.53            0.53
# 214  2019     11     0.63           0.63            0.63
# 215  2019     12     0.59           0.59            0.59
#
# [216 rows x 5 columns]

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            216 non-null    int64
#  1   Month           216 non-null    int64
#  2   cc_past         216 non-null    float64
#  3   cc_pasttopast   216 non-null    float64
#  4   Cloud Coverage  216 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 8.6 KB

# %%
#Creating correlation for precipitation
#Creating the correlation matrix for the features
corr_matrix=cc.corr()
corr_matrix
# Out:
#                         Year         Month   cc_past  cc_pasttopast  \
# Year            1.000000e+00  4.861859e-15 -0.022738      -0.024348
# Month           4.861859e-15  1.000000e+00 -0.333878      -0.328033
# cc_past        -2.273793e-02 -3.338781e-01  1.000000       0.927981
# cc_pasttopast  -2.434758e-02 -3.280330e-01  0.927981       1.000000
# Cloud Coverage -2.162758e-02 -3.388807e-01  0.929115       0.931824
#
#                 Cloud Coverage
# Year                 -0.021628
# Month                -0.338881
# cc_past               0.929115
# cc_pasttopast         0.931824
# Cloud Coverage        1.000000

# %%
mask = np.zeros_like(corr_matrix, dtype=bool)
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(5, 4)) 
heatmap = sns.heatmap(corr_matrix, mask = mask,square = True,linewidths = .5, cmap = 'coolwarm', cbar_kws = {'shrink': .4, 'ticks' : [-1, -.5, 0, 0.5, 1]},vmin = -1, vmax = 1,annot = True,annot_kws = {'size': 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
cc=cc.drop(['Year','Month'],axis=1)

# %%
cc.shape
# Out:
# (216, 3)

# %%
cc=cc.iloc[:,:].values

# %%
cc
# Out:
# array([[0.66, 0.69, 0.69],
#        [0.71, 0.68, 0.66],
#        [0.71, 0.7 , 0.68],
#        [0.62, 0.67, 0.63],
#        [0.62, 0.57, 0.62],
#        [0.41, 0.4 , 0.34],
#        [0.35, 0.37, 0.41],
#        [0.38, 0.36, 0.33],
#        [0.46, 0.48, 0.5 ],
#        [0.53, 0.55, 0.56],
#        [0.65, 0.63, 0.66],
#        [0.65, 0.67, 0.67],
#        [0.69, 0.66, 0.66],
#        [0.66, 0.71, 0.67],
#        [0.68, 0.71, 0.66],
#        [0.63, 0.62, 0.63],
#        [0.62, 0.62, 0.67],
#        [0.34, 0.41, 0.41],
#        [0.41, 0.35, 0.33],
#        [0.33, 0.38, 0.37],
#        [0.5 , 0.46, 0.47],
#        [0.56, 0.53, 0.57],
#        [0.66, 0.65, 0.63],
#        [0.67, 0.65, 0.68],
#        [0.66, 0.69, 0.68],
#        [0.67, 0.66, 0.69],
#        [0.66, 0.68, 0.71],
#        [0.63, 0.63, 0.68],
#        [0.67, 0.62, 0.55],
#        [0.41, 0.34, 0.39],
#        [0.33, 0.41, 0.37],
#        [0.37, 0.33, 0.36],
#        [0.47, 0.5 , 0.44],
#        [0.57, 0.56, 0.58],
#        [0.63, 0.66, 0.6 ],
#        [0.68, 0.67, 0.68],
#        [0.68, 0.66, 0.66],
#        [0.69, 0.67, 0.66],
#        [0.71, 0.66, 0.7 ],
#        [0.68, 0.63, 0.62],
#        [0.55, 0.67, 0.66],
#        [0.39, 0.41, 0.39],
#        [0.37, 0.33, 0.29],
#        [0.36, 0.37, 0.32],
#        [0.44, 0.47, 0.35],
#        [0.58, 0.57, 0.54],
#        [0.6 , 0.63, 0.67],
#        [0.68, 0.68, 0.65],
#        [0.66, 0.68, 0.71],
#        [0.66, 0.69, 0.69],
#        [0.7 , 0.71, 0.64],
#        [0.62, 0.68, 0.65],
#        [0.66, 0.55, 0.61],
#        [0.39, 0.39, 0.42],
#        [0.29, 0.37, 0.31],
#        [0.32, 0.36, 0.32],
#        [0.35, 0.44, 0.43],
#        [0.54, 0.58, 0.52],
#        [0.67, 0.6 , 0.53],
#        [0.65, 0.68, 0.64],
#        [0.71, 0.66, 0.68],
#        [0.69, 0.66, 0.68],
#        [0.64, 0.7 , 0.67],
#        [0.65, 0.62, 0.63],
#        [0.61, 0.66, 0.62],
#        [0.42, 0.39, 0.38],
#        [0.31, 0.29, 0.31],
#        [0.32, 0.32, 0.3 ],
#        [0.43, 0.35, 0.33],
#        [0.52, 0.54, 0.55],
#        [0.53, 0.67, 0.66],
#        [0.64, 0.65, 0.63],
#        [0.68, 0.71, 0.69],
#        [0.68, 0.69, 0.67],
#        [0.67, 0.64, 0.65],
#        [0.63, 0.65, 0.68],
#        [0.62, 0.61, 0.67],
#        [0.38, 0.42, 0.46],
#        [0.31, 0.31, 0.44],
#        [0.3 , 0.32, 0.42],
#        [0.33, 0.43, 0.49],
#        [0.55, 0.52, 0.63],
#        [0.66, 0.53, 0.61],
#        [0.63, 0.64, 0.64],
#        [0.69, 0.68, 0.68],
#        [0.67, 0.68, 0.7 ],
#        [0.65, 0.67, 0.67],
#        [0.68, 0.63, 0.66],
#        [0.67, 0.62, 0.63],
#        [0.46, 0.38, 0.54],
#        [0.44, 0.31, 0.36],
#        [0.42, 0.3 , 0.47],
#        [0.49, 0.33, 0.49],
#        [0.63, 0.55, 0.56],
#        [0.61, 0.66, 0.56],
#        [0.64, 0.63, 0.65],
#        [0.68, 0.69, 0.63],
#        [0.7 , 0.67, 0.67],
#        [0.67, 0.65, 0.67],
#        [0.66, 0.68, 0.65],
#        [0.63, 0.67, 0.65],
#        [0.54, 0.46, 0.48],
#        [0.36, 0.44, 0.36],
#        [0.47, 0.42, 0.41],
#        [0.49, 0.49, 0.47],
#        [0.56, 0.63, 0.57],
#        [0.56, 0.61, 0.54],
#        [0.65, 0.64, 0.65],
#        [0.63, 0.68, 0.68],
#        [0.67, 0.7 , 0.69],
#        [0.67, 0.67, 0.7 ],
#        [0.65, 0.66, 0.66],
#        [0.65, 0.63, 0.64],
#        [0.48, 0.54, 0.44],
#        [0.36, 0.36, 0.38],
#        [0.41, 0.47, 0.41],
#        [0.47, 0.49, 0.47],
#        [0.57, 0.56, 0.56],
#        [0.54, 0.56, 0.63],
#        [0.65, 0.65, 0.69],
#        [0.68, 0.63, 0.69],
#        [0.69, 0.67, 0.67],
#        [0.7 , 0.67, 0.72],
#        [0.66, 0.65, 0.65],
#        [0.64, 0.65, 0.67],
#        [0.44, 0.48, 0.53],
#        [0.38, 0.36, 0.37],
#        [0.41, 0.41, 0.44],
#        [0.47, 0.47, 0.47],
#        [0.56, 0.57, 0.56],
#        [0.63, 0.54, 0.62],
#        [0.69, 0.65, 0.67],
#        [0.69, 0.68, 0.66],
#        [0.67, 0.69, 0.66],
#        [0.72, 0.7 , 0.65],
#        [0.65, 0.66, 0.66],
#        [0.67, 0.64, 0.6 ],
#        [0.53, 0.44, 0.39],
#        [0.37, 0.38, 0.26],
#        [0.44, 0.41, 0.38],
#        [0.47, 0.47, 0.46],
#        [0.56, 0.56, 0.5 ],
#        [0.62, 0.63, 0.6 ],
#        [0.67, 0.69, 0.66],
#        [0.66, 0.69, 0.62],
#        [0.66, 0.67, 0.65],
#        [0.65, 0.72, 0.63],
#        [0.66, 0.65, 0.61],
#        [0.6 , 0.67, 0.6 ],
#        [0.39, 0.53, 0.52],
#        [0.26, 0.37, 0.31],
#        [0.38, 0.44, 0.37],
#        [0.46, 0.47, 0.44],
#        [0.5 , 0.56, 0.54],
#        [0.6 , 0.62, 0.61],
#        [0.66, 0.67, 0.62],
#        [0.62, 0.66, 0.63],
#        [0.65, 0.66, 0.67],
#        [0.63, 0.65, 0.62],
#        [0.61, 0.66, 0.63],
#        [0.6 , 0.6 , 0.6 ],
#        [0.52, 0.39, 0.41],
#        [0.31, 0.26, 0.37],
#        [0.37, 0.38, 0.4 ],
#        [0.44, 0.46, 0.5 ],
#        [0.54, 0.5 , 0.55],
#        [0.61, 0.6 , 0.58],
#        [0.62, 0.66, 0.64],
#        [0.63, 0.62, 0.63],
#        [0.67, 0.65, 0.63],
#        [0.62, 0.63, 0.66],
#        [0.63, 0.61, 0.63],
#        [0.6 , 0.6 , 0.62],
#        [0.41, 0.52, 0.4 ],
#        [0.37, 0.31, 0.27],
#        [0.4 , 0.37, 0.35],
#        [0.5 , 0.44, 0.39],
#        [0.55, 0.54, 0.54],
#        [0.58, 0.61, 0.66],
#        [0.64, 0.62, 0.63],
#        [0.63, 0.63, 0.66],
#        [0.63, 0.67, 0.69],
#        [0.66, 0.62, 0.68],
#        [0.63, 0.63, 0.66],
#        [0.62, 0.6 , 0.62],
#        [0.4 , 0.41, 0.44],
#        [0.27, 0.37, 0.33],
#        [0.35, 0.4 , 0.38],
#        [0.39, 0.5 , 0.44],
#        [0.54, 0.55, 0.53],
#        [0.66, 0.58, 0.63],
#        [0.63, 0.64, 0.59],
#        [0.66, 0.63, 0.66],
#        [0.69, 0.63, 0.69],
#        [0.68, 0.66, 0.68],
#        [0.66, 0.63, 0.66],
#        [0.62, 0.62, 0.62],
#        [0.44, 0.4 , 0.44],
#        [0.33, 0.27, 0.33],
#        [0.38, 0.35, 0.38],
#        [0.44, 0.39, 0.44],
#        [0.53, 0.54, 0.53],
#        [0.63, 0.66, 0.63],
#        [0.59, 0.63, 0.59],
#        [0.66, 0.66, 0.66],
#        [0.69, 0.69, 0.69],
#        [0.68, 0.68, 0.68],
#        [0.66, 0.66, 0.66],
#        [0.62, 0.62, 0.62],
#        [0.44, 0.44, 0.44],
#        [0.33, 0.33, 0.33],
#        [0.38, 0.38, 0.38],
#        [0.44, 0.44, 0.44],
#        [0.53, 0.53, 0.53],
#        [0.63, 0.63, 0.63],
#        [0.59, 0.59, 0.59]])

# %%
X=cc[:,:-1]
y=cc[:,-1]

# %%
X
# Out:
# array([[0.66, 0.69],
#        [0.71, 0.68],
#        [0.71, 0.7 ],
#        [0.62, 0.67],
#        [0.62, 0.57],
#        [0.41, 0.4 ],
#        [0.35, 0.37],
#        [0.38, 0.36],
#        [0.46, 0.48],
#        [0.53, 0.55],
#        [0.65, 0.63],
#        [0.65, 0.67],
#        [0.69, 0.66],
#        [0.66, 0.71],
#        [0.68, 0.71],
#        [0.63, 0.62],
#        [0.62, 0.62],
#        [0.34, 0.41],
#        [0.41, 0.35],
#        [0.33, 0.38],
#        [0.5 , 0.46],
#        [0.56, 0.53],
#        [0.66, 0.65],
#        [0.67, 0.65],
#        [0.66, 0.69],
#        [0.67, 0.66],
#        [0.66, 0.68],
#        [0.63, 0.63],
#        [0.67, 0.62],
#        [0.41, 0.34],
#        [0.33, 0.41],
#        [0.37, 0.33],
#        [0.47, 0.5 ],
#        [0.57, 0.56],
#        [0.63, 0.66],
#        [0.68, 0.67],
#        [0.68, 0.66],
#        [0.69, 0.67],
#        [0.71, 0.66],
#        [0.68, 0.63],
#        [0.55, 0.67],
#        [0.39, 0.41],
#        [0.37, 0.33],
#        [0.36, 0.37],
#        [0.44, 0.47],
#        [0.58, 0.57],
#        [0.6 , 0.63],
#        [0.68, 0.68],
#        [0.66, 0.68],
#        [0.66, 0.69],
#        [0.7 , 0.71],
#        [0.62, 0.68],
#        [0.66, 0.55],
#        [0.39, 0.39],
#        [0.29, 0.37],
#        [0.32, 0.36],
#        [0.35, 0.44],
#        [0.54, 0.58],
#        [0.67, 0.6 ],
#        [0.65, 0.68],
#        [0.71, 0.66],
#        [0.69, 0.66],
#        [0.64, 0.7 ],
#        [0.65, 0.62],
#        [0.61, 0.66],
#        [0.42, 0.39],
#        [0.31, 0.29],
#        [0.32, 0.32],
#        [0.43, 0.35],
#        [0.52, 0.54],
#        [0.53, 0.67],
#        [0.64, 0.65],
#        [0.68, 0.71],
#        [0.68, 0.69],
#        [0.67, 0.64],
#        [0.63, 0.65],
#        [0.62, 0.61],
#        [0.38, 0.42],
#        [0.31, 0.31],
#        [0.3 , 0.32],
#        [0.33, 0.43],
#        [0.55, 0.52],
#        [0.66, 0.53],
#        [0.63, 0.64],
#        [0.69, 0.68],
#        [0.67, 0.68],
#        [0.65, 0.67],
#        [0.68, 0.63],
#        [0.67, 0.62],
#        [0.46, 0.38],
#        [0.44, 0.31],
#        [0.42, 0.3 ],
#        [0.49, 0.33],
#        [0.63, 0.55],
#        [0.61, 0.66],
#        [0.64, 0.63],
#        [0.68, 0.69],
#        [0.7 , 0.67],
#        [0.67, 0.65],
#        [0.66, 0.68],
#        [0.63, 0.67],
#        [0.54, 0.46],
#        [0.36, 0.44],
#        [0.47, 0.42],
#        [0.49, 0.49],
#        [0.56, 0.63],
#        [0.56, 0.61],
#        [0.65, 0.64],
#        [0.63, 0.68],
#        [0.67, 0.7 ],
#        [0.67, 0.67],
#        [0.65, 0.66],
#        [0.65, 0.63],
#        [0.48, 0.54],
#        [0.36, 0.36],
#        [0.41, 0.47],
#        [0.47, 0.49],
#        [0.57, 0.56],
#        [0.54, 0.56],
#        [0.65, 0.65],
#        [0.68, 0.63],
#        [0.69, 0.67],
#        [0.7 , 0.67],
#        [0.66, 0.65],
#        [0.64, 0.65],
#        [0.44, 0.48],
#        [0.38, 0.36],
#        [0.41, 0.41],
#        [0.47, 0.47],
#        [0.56, 0.57],
#        [0.63, 0.54],
#        [0.69, 0.65],
#        [0.69, 0.68],
#        [0.67, 0.69],
#        [0.72, 0.7 ],
#        [0.65, 0.66],
#        [0.67, 0.64],
#        [0.53, 0.44],
#        [0.37, 0.38],
#        [0.44, 0.41],
#        [0.47, 0.47],
#        [0.56, 0.56],
#        [0.62, 0.63],
#        [0.67, 0.69],
#        [0.66, 0.69],
#        [0.66, 0.67],
#        [0.65, 0.72],
#        [0.66, 0.65],
#        [0.6 , 0.67],
#        [0.39, 0.53],
#        [0.26, 0.37],
#        [0.38, 0.44],
#        [0.46, 0.47],
#        [0.5 , 0.56],
#        [0.6 , 0.62],
#        [0.66, 0.67],
#        [0.62, 0.66],
#        [0.65, 0.66],
#        [0.63, 0.65],
#        [0.61, 0.66],
#        [0.6 , 0.6 ],
#        [0.52, 0.39],
#        [0.31, 0.26],
#        [0.37, 0.38],
#        [0.44, 0.46],
#        [0.54, 0.5 ],
#        [0.61, 0.6 ],
#        [0.62, 0.66],
#        [0.63, 0.62],
#        [0.67, 0.65],
#        [0.62, 0.63],
#        [0.63, 0.61],
#        [0.6 , 0.6 ],
#        [0.41, 0.52],
#        [0.37, 0.31],
#        [0.4 , 0.37],
#        [0.5 , 0.44],
#        [0.55, 0.54],
#        [0.58, 0.61],
#        [0.64, 0.62],
#        [0.63, 0.63],
#        [0.63, 0.67],
#        [0.66, 0.62],
#        [0.63, 0.63],
#        [0.62, 0.6 ],
#        [0.4 , 0.41],
#        [0.27, 0.37],
#        [0.35, 0.4 ],
#        [0.39, 0.5 ],
#        [0.54, 0.55],
#        [0.66, 0.58],
#        [0.63, 0.64],
#        [0.66, 0.63],
#        [0.69, 0.63],
#        [0.68, 0.66],
#        [0.66, 0.63],
#        [0.62, 0.62],
#        [0.44, 0.4 ],
#        [0.33, 0.27],
#        [0.38, 0.35],
#        [0.44, 0.39],
#        [0.53, 0.54],
#        [0.63, 0.66],
#        [0.59, 0.63],
#        [0.66, 0.66],
#        [0.69, 0.69],
#        [0.68, 0.68],
#        [0.66, 0.66],
#        [0.62, 0.62],
#        [0.44, 0.44],
#        [0.33, 0.33],
#        [0.38, 0.38],
#        [0.44, 0.44],
#        [0.53, 0.53],
#        [0.63, 0.63],
#        [0.59, 0.59]])

# %%
y
# Out:
# array([0.69, 0.66, 0.68, 0.63, 0.62, 0.34, 0.41, 0.33, 0.5 , 0.56, 0.66,
#        0.67, 0.66, 0.67, 0.66, 0.63, 0.67, 0.41, 0.33, 0.37, 0.47, 0.57,
#        0.63, 0.68, 0.68, 0.69, 0.71, 0.68, 0.55, 0.39, 0.37, 0.36, 0.44,
#        0.58, 0.6 , 0.68, 0.66, 0.66, 0.7 , 0.62, 0.66, 0.39, 0.29, 0.32,
#        0.35, 0.54, 0.67, 0.65, 0.71, 0.69, 0.64, 0.65, 0.61, 0.42, 0.31,
#        0.32, 0.43, 0.52, 0.53, 0.64, 0.68, 0.68, 0.67, 0.63, 0.62, 0.38,
#        0.31, 0.3 , 0.33, 0.55, 0.66, 0.63, 0.69, 0.67, 0.65, 0.68, 0.67,
#        0.46, 0.44, 0.42, 0.49, 0.63, 0.61, 0.64, 0.68, 0.7 , 0.67, 0.66,
#        0.63, 0.54, 0.36, 0.47, 0.49, 0.56, 0.56, 0.65, 0.63, 0.67, 0.67,
#        0.65, 0.65, 0.48, 0.36, 0.41, 0.47, 0.57, 0.54, 0.65, 0.68, 0.69,
#        0.7 , 0.66, 0.64, 0.44, 0.38, 0.41, 0.47, 0.56, 0.63, 0.69, 0.69,
#        0.67, 0.72, 0.65, 0.67, 0.53, 0.37, 0.44, 0.47, 0.56, 0.62, 0.67,
#        0.66, 0.66, 0.65, 0.66, 0.6 , 0.39, 0.26, 0.38, 0.46, 0.5 , 0.6 ,
#        0.66, 0.62, 0.65, 0.63, 0.61, 0.6 , 0.52, 0.31, 0.37, 0.44, 0.54,
#        0.61, 0.62, 0.63, 0.67, 0.62, 0.63, 0.6 , 0.41, 0.37, 0.4 , 0.5 ,
#        0.55, 0.58, 0.64, 0.63, 0.63, 0.66, 0.63, 0.62, 0.4 , 0.27, 0.35,
#        0.39, 0.54, 0.66, 0.63, 0.66, 0.69, 0.68, 0.66, 0.62, 0.44, 0.33,
#        0.38, 0.44, 0.53, 0.63, 0.59, 0.66, 0.69, 0.68, 0.66, 0.62, 0.44,
#        0.33, 0.38, 0.44, 0.53, 0.63, 0.59, 0.66, 0.69, 0.68, 0.66, 0.62,
#        0.44, 0.33, 0.38, 0.44, 0.53, 0.63, 0.59])

# %%
X.shape
# Out:
# (216, 2)

# %%
y.shape
# Out:
# (216,)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
X_train,y_train=np.array(X_train),np.array(y_train)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %% [markdown]
# # Linear Regressor

# %%
li=LinearRegression()

# %%
li.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Lir_ypred= li.predict(X_test)
Lir_ypred
# Out:
# array([0.66262355, 0.30933215, 0.56551189, 0.6819374 , 0.6824798 ,
#        0.5877558 , 0.65188182, 0.34958706, 0.33190041, 0.45288318,
#        0.53361105, 0.35707438, 0.54674044, 0.67629534, 0.4560313 ,
#        0.67738014, 0.63929484, 0.63527997, 0.3645617 , 0.64168249,
#        0.64786696, 0.41045867, 0.44507151, 0.66772321, 0.40698621,
#        0.63712523, 0.70125125, 0.6438521 , 0.47241509, 0.53252625,
#        0.56551189, 0.63875243, 0.36781611, 0.67629534, 0.66208115,
#        0.42977252, 0.34101493, 0.70070885, 0.67119567, 0.66262355,
#        0.59556747, 0.65242422, 0.63929484, 0.65133942])

# %%
Linear=pd.DataFrame({'Actual':y_test,'Predicted':Lir_ypred})
Linear
# Out:
#     Actual  Predicted
# 0     0.62   0.662624
# 1     0.31   0.309332
# 2     0.56   0.565512
# 3     0.63   0.681937
# 4     0.69   0.682480
# 5     0.56   0.587756
# 6     0.65   0.651882
# 7     0.32   0.349587
# 8     0.33   0.331900
# 9     0.44   0.452883
# 10    0.54   0.533611
# 11    0.36   0.357074
# 12    0.53   0.546740
# 13    0.67   0.676295
# 14    0.41   0.456031
# 15    0.66   0.677380
# 16    0.63   0.639295
# 17    0.60   0.635280
# 18    0.47   0.364562
# 19    0.63   0.641682
# 20    0.69   0.647867
# 21    0.38   0.410459
# 22    0.44   0.445072
# 23    0.71   0.667723
# 24    0.39   0.406986
# 25    0.68   0.637125
# 26    0.64   0.701251
# 27    0.60   0.643852
# 28    0.39   0.472415
# 29    0.55   0.532526
# 30    0.58   0.565512
# 31    0.62   0.638752
# 32    0.38   0.367816
# 33    0.66   0.676295
# 34    0.69   0.662081
# 35    0.38   0.429773
# 36    0.31   0.341015
# 37    0.68   0.700709
# 38    0.66   0.671196
# 39    0.65   0.662624
# 40    0.66   0.595567
# 41    0.63   0.652424
# 42    0.64   0.639295
# 43    0.62   0.651339

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
#print('Mean Absolute Error:',mean_absolute_error(y_test,Lir_ypred))
print('Mean squared Error:',mean_squared_error(y_test,Lir_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lir_ypred)))
print('R2_Score:',r2_score(y_test,Lir_ypred))
# Out:
# Mean squared Error: 0.001198987015046446
# Root Mean Squared Error: 0.034626391886051974
# R2_Score: 0.9251445081158765

# %%
linear_r2_score=r2_score(y_test,Lir_ypred)
linear_r2_score
# Out:
# 0.9251445081158765

# %% [markdown]
# # Lasso Regressor

# %%
#Lasso Regressor
lass=Lasso(alpha=0.0001)
lass.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
Lass_ypred= lass.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,Lass_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lass_ypred)))
print('R2_Score:',r2_score(y_test,Lass_ypred))
# Out:
# Mean squared Error: 0.0011963452029689768
# Root Mean Squared Error: 0.03458822347228861
# R2_Score: 0.9253094424646581

# %%
lasso_r2_score=r2_score(y_test,Lass_ypred)
lasso_r2_score
# Out:
# 0.9253094424646581

# %% [markdown]
# # Ridge Regressor

# %%
#RIdge
rid=Ridge(alpha=0.0001)
rid.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.0001)

# %%
rid_ypred= rid.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,rid_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rid_ypred)))
print('R2_Score:',r2_score(y_test,rid_ypred))
# Out:
# Mean squared Error: 0.001198974801623695
# Root Mean Squared Error: 0.034626215525576785
# R2_Score: 0.9251452706276936

# %%
ridge_r2_score=r2_score(y_test,rid_ypred)
ridge_r2_score
# Out:
# 0.9251452706276936

# %% [markdown]
# # Decision Tree Regressor

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_ypred= dt.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,dt_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dt_ypred)))
print('R2_Score:',r2_score(y_test,dt_ypred))
# Out:
# Mean squared Error: 0.00400965909090909
# Root Mean Squared Error: 0.06332186897833236
# R2_Score: 0.7496678447964502

# %%
decisiontree_r2_score=r2_score(y_test,dt_ypred)
decisiontree_r2_score
# Out:
# 0.7496678447964502

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn=KNeighborsRegressor(n_neighbors=15)
kn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=15)

# %%
kn1_pred=kn.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,kn1_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,kn1_pred)))
print('R2_Score:',r2_score(y_test,kn1_pred))
# Out:
# Mean squared Error: 0.0011909292929292924
# Root Mean Squared Error: 0.034509843420816796
# R2_Score: 0.9256475700714905

# %%
kneighbour_r2_score=r2_score(y_test,kn1_pred)
kneighbour_r2_score
# Out:
# 0.9256475700714905

# %% [markdown]
# # SVR rbf

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf')
svr.fit(X_train,y_train)
svr_pred=svr.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,svr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,svr_pred)))
print('R2_Score:',r2_score(y_test,svr_pred))
# Out:
# Mean squared Error: 0.0018074909847399427
# Root Mean Squared Error: 0.04251459731362797
# R2_Score: 0.8871542184853553

# %%
svr_r2_score=r2_score(y_test,svr_pred)
svr_r2_score
# Out:
# 0.8871542184853553

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(X_train, y_train);

# %%
rf_pred=rf.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,rf_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rf_pred)))
print('R2_Score:',r2_score(y_test,rf_pred))
# Out:
# Mean squared Error: 0.0021511892928577055
# Root Mean Squared Error: 0.0463809151791737
# R2_Score: 0.8656963498086877

# %%
randomforest_r2_score=r2_score(y_test,rf_pred)
randomforest_r2_score
# Out:
# 0.8656963498086877

# %% [markdown]
# # Bayes Regressor

# %%
from sklearn.linear_model import BayesianRidge
br=BayesianRidge()
br.fit(X_train,y_train)
y_pred=br.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('R2_Score:',r2_score(y_test,y_pred))
# Out:
# Mean squared Error: 0.0011981683571958717
# Root Mean Squared Error: 0.03461456856868032
# R2_Score: 0.9251956187912386

# %%
bayes_r2_score=r2_score(y_test,y_pred)
bayes_r2_score
# Out:
# 0.9251956187912386

# %%
Regressors=['Linear','Lasso','Ridge','DecisionTree','KNeighbour','SVR','RandomForest','Bayesian']
R2_Score=[linear_r2_score,lasso_r2_score,ridge_r2_score,decisiontree_r2_score,kneighbour_r2_score,svr_r2_score,randomforest_r2_score,bayes_r2_score]

# %%
plt.figure(figsize=(15,4))
plt.plot(Regressors,R2_Score, color = 'Red')

plt.title('Comparision between different Regressors',fontsize=15)
plt.xlabel('Regressors',fontsize=15)
plt.ylabel('Accuracy Values',fontsize=15)
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20220\2049796945.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # KNeighbour Regressor with is best for cloudcover prediction with accuracy of 92.6% followed by Lasso Regressor with 92.53%

# %%
cc2020=pd.read_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\cloudcover\cloudcover2020pred.csv")

# %%
cc2020.drop(['Year','Month'],axis=1,inplace=True)

# %%
cc2020=cc2020.iloc[:,:].values

# %%
cc2020
# Out:
# array([[0.66, 0.66],
#        [0.69, 0.69],
#        [0.68, 0.68],
#        [0.66, 0.66],
#        [0.62, 0.62],
#        [0.44, 0.44],
#        [0.33, 0.33],
#        [0.38, 0.38],
#        [0.44, 0.44],
#        [0.53, 0.53],
#        [0.63, 0.63],
#        [0.59, 0.59]])

# %%
cc2020_pred=[]

# %%
cc2020_pred=kn.predict(cc2020)

# %%
cc2020_pred
# Out:
# array([0.662     , 0.678     , 0.676     , 0.662     , 0.63933333,
#        0.44066667, 0.348     , 0.37866667, 0.44066667, 0.534     ,
#        0.638     , 0.59866667])

# %%
cloud_data=pd.DataFrame(data=cc2020_pred)
cloud_data
# Out:
#            0
# 0   0.662000
# 1   0.678000
# 2   0.676000
# 3   0.662000
# 4   0.639333
# 5   0.440667
# 6   0.348000
# 7   0.378667
# 8   0.440667
# 9   0.534000
# 10  0.638000
# 11  0.598667

# %%
cloud_data.to_csv(r"C:\Users\HP\Downloads\Crop-yield-prediction-using-weather-data-and-NDVI-time-series-main\Phase1\csv\cloudcover\2020cloudcover.csv")
